# %%
import pandas as pd 

pd.read_csv("https://raw.githubusercontent.com/data301-2020-winter1/course-project-group_118/main/data/raw/plays.csv?token=AMF4C2HE6URWR6MJSMCDN527Y2K64")
# Out:
#                play_id     game_id  play_num  team_id_for  team_id_against  \
# 0         2010020316_2  2010020316         2          NaN              NaN
# 1         2010020316_3  2010020316         3          NaN              NaN
# 2         2010020316_4  2010020316         4         18.0             19.0
# 3         2010020316_5  2010020316         5         19.0             18.0
# 4         2010020316_6  2010020316         6         19.0             18.0
# ...                ...         ...       ...          ...              ...
# 149071  2018030415_347  2018030415       347          6.0             19.0
# 149072  2018030415_348  2018030415       348          6.0             19.0
# 149073  2018030415_349  2018030415       349          NaN              NaN
# 149074  2018030415_350  2018030415       350          NaN              NaN
# 149075  2018030415_351  2018030415       351          NaN              NaN
#
# ...
